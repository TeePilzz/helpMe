# %% [markdown]
# <a href="https://colab.research.google.com/github/TeePilzz/helpMe/blob/main/co_occurence_practice_Stepanets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://gist.githubusercontent.com/phillipj/4944029/raw/75ba2243dd5ec2875f629bf5d79f6c1e4b5a8b46/alice_in_wonderland.txt
# Out:
# --2024-11-19 17:36:01--  https://gist.githubusercontent.com/phillipj/4944029/raw/75ba2243dd5ec2875f629bf5d79f6c1e4b5a8b46/alice_in_wonderland.txt
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148574 (145K) [text/plain]
# Saving to: ‘alice_in_wonderland.txt’
#
# alice_in_wonderland 100%[===================>] 145.09K  --.-KB/s    in 0.01s
#
# 2024-11-19 17:36:01 (12.3 MB/s) - ‘alice_in_wonderland.txt’ saved [148574/148574]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'alice_in_wonderland.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[100:1100]
# Out:
# "          lewis carroll\n\n               the millennium fulcrum edition 3.0\n\n\n\n\n                            chapter i\n\n                      down the rabbit-hole\n\n\n  alice was beginning to get very tired of sitting by her sister\non the bank, and of having nothing to do:  once or twice she had\npeeped into the book her sister was reading, but it had no\npictures or conversations in it, `and what is the use of a book,'\nthought alice `without pictures or conversation?'\n\n  so she was considering in her own mind (as well as she could,\nfor the hot day made her feel very sleepy and stupid), whether\nthe pleasure of making a daisy-chain would be worth the trouble\nof getting up and picking the daisies, when suddenly a white\nrabbit with pink eyes ran close by her.\n\n  there was nothing so very remarkable in that; nor did alice\nthink it so very much out of the way to hear the rabbit say to\nitself, `oh dear!  oh dear!  i shall be late!'  (when she thought\nit over afterwards, it occurred to her that she"

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[100:1100]
# Out:
# '        lewis carroll\n\n               the millennium fulcrum edition .\n\n\n\n\n                            chapter i\n\n                      down the rabbithole\n\n\n  alice was beginning to get very tired of sitting by her sister\non the bank and of having nothing to do  once or twice she had\npeeped into the book her sister was reading but it had no\npictures or conversations in it and what is the use of a book\nthought alice without pictures or conversation?\n\n  so she was considering in her own mind as well as she could\nfor the hot day made her feel very sleepy and stupid whether\nthe pleasure of making a daisychain would be worth the trouble\nof getting up and picking the daisies when suddenly a white\nrabbit with pink eyes ran close by her.\n\n  there was nothing so very remarkable in that nor did alice\nthink it so very much out of the way to hear the rabbit say to\nitself oh dear!  oh dear!  i shall be late!  when she thought\nit over afterwards it occurred to her that she ought to have\nwondered at'

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1:3]
# Out:
# ['\n\n\n\n\n                            chapter i\n\n                      down the rabbithole\n\n\n  alice was beginning to get very tired of sitting by her sister\non the bank and of having nothing to do  once or twice she had\npeeped into the book her sister was reading but it had no\npictures or conversations in it and what is the use of a book\nthought alice without pictures or conversation',
#  '\n\n  so she was considering in her own mind as well as she could\nfor the hot day made her feel very sleepy and stupid whether\nthe pleasure of making a daisychain would be worth the trouble\nof getting up and picking the daisies when suddenly a white\nrabbit with pink eyes ran close by her']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[3]
# Out:
# ['there',
#  'was',
#  'nothing',
#  'so',
#  'very',
#  'remarkable',
#  'in',
#  'that',
#  'nor',
#  'did',
#  'alice',
#  'think',
#  'it',
#  'so',
#  'very',
#  'much',
#  'out',
#  'of',
#  'the',
#  'way',
#  'to',
#  'hear',
#  'the',
#  'rabbit',
#  'say',
#  'to',
#  'itself',
#  'oh',
#  'dear']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = ["<START>"] + sentence + ["<END>"]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

co_occurrence['dear']
# Out:
# defaultdict(int,
#             {'oh': 15,
#              '<END>': 42,
#              'my': 33,
#              'what': 3,
#              'talking': 3,
#              'dear': 6,
#              'andoh': 6,
#              'how': 3,
#              'isoh': 3,
#              'again': 3,
#              'a': 6,
#              'quiet': 3,
#              'mouse': 3,
#              'trial': 3,
#              'sir': 3,
#              'dinah': 3,
#              'paws': 3,
#              'little': 3,
#              'said': 3,
#              'she': 3,
#              'you': 6,
#              'old': 3,
#              'and': 3,
#              'i': 3,
#              'alice': 3,
#              'dream': 3,
#              'certainly': 3})

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['<START>',
#  'alices',
#  'adventures',
#  'in',
#  'wonderland',
#  'lewis',
#  'carroll',
#  'the',
#  'millennium',
#  'fulcrum']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#              <START>  alices  adventures  in  wonderland  lewis  carroll  the  \
# <START>            0       6           0  33           0      0        0  336
# alices             6       0           6   0           3      0        0    0
# adventures         0       6           0   6           0      0        0    3
# in                33       0           6   0           9      0        0  234
# wonderland         0       3           0   9           0      3        0    0
# ...              ...     ...         ...  ..         ...    ...      ...  ...
# sorrows            0       0           0   0           0      0        0    0
# joys               0       0           0   0           0      0        0    0
# remembering        0       0           0   0           0      0        0    0
# childlife          0       0           0   0           0      0        0    0
# happy              0       0           0   0           0      0        0    3
#
#              millennium  fulcrum  ...  riper  years  loving  childhood  \
# <START>               0        0  ...      0      0       0          0
# alices                0        0  ...      0      0       0          0
# adventures            0        0  ...      0      0       0          0
# in                    0        0  ...      0      0       0          0
# wonderland            0        0  ...      0      0       0          0
# ...                 ...      ...  ...    ...    ...     ...        ...
# sorrows               0        0  ...      0      0       0          0
# joys                  0        0  ...      0      0       0          0
# remembering           0        0  ...      0      0       0          0
# childlife             0        0  ...      0      0       0          0
# happy                 0        0  ...      0      0       0          0
#
#              gather  sorrows  joys  remembering  childlife  happy
# <START>           0        0     0            0          0      0
# alices            0        0     0            0          0      0
# adventures        0        0     0            0          0      0
# in                0        0     0            0          0      0
# wonderland        0        0     0            0          0      0
# ...             ...      ...   ...          ...        ...    ...
# sorrows           0        0     0            0          0      0
# joys              0        0     0            3          0      0
# remembering       0        0     3            0          0      0
# childlife         0        0     0            0          0      0
# happy             0        0     0            0          0      0
#
# [2744 rows x 2744 columns]
