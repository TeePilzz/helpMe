# %%
Система обрабатывает языковую пару «русский – немецкий».
Токенизация: Разбиваем текст на отдельные слова и знаки препинания.
Лемматизация: Приводим слова к их начальной форме.
Морфологический анализ: Определяем части речи и другие морфологические характеристики слов.
Синтаксический разбор: Анализируем структуру предложений и связи между словами.

Языковые правила
Перевод существительных: Существительные переводятся напрямую, но необходимо учитывать род и падеж.
Перевод глаголов: Глаголы переводятся с учётом времени, лица и числа.
Перевод прилагательных: Прилагательные должны согласовываться с существительными в роде, числе и падеже.
Порядок слов: Немецкий язык имеет другой порядок слов, поэтому важно правильно организовать переводимое предложение.

После того как все языковые правила применены, система пересобирает переведённые элементы в правильный порядок, соответствующий немецкому языку, и формирует итоговое предложение.

Какие библиотеки NLP вы будете использовать?
NLTK или SpaCy
Pattern
Polyglot
